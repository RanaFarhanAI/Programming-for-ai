# %% [markdown]
# # Rana Farhan Mehboob
# #       199
# #     BSAI-4C
# #      PAI
# #     SIR RASIK ALI

# %% [markdown]
# Q1:

# %%
a = 4
for i in range(a):
    for j in range(a):
        print("|", end=' ')
        print("*", end=' ')
    print()
# Out:
# | * | * | * | *
# | * | * | * | *
# | * | * | * | *
# | * | * | * | *

# %% [markdown]
# Q2

# %%
b = 4
val = [['.' for i in range(b)] for j in range(b)]

val[0][1] = 'Q'

for i in range(b):
    print("+" + "---+" * b)  
    for j in range(b):
        print("|", end=' ')
        print(val[i][j], end=' ')  
    print("|")
print("+" + "---+" * b)
# Out:
# +---+---+---+---+
# | . | Q | . | . |
# +---+---+---+---+
# | . | . | . | . |
# +---+---+---+---+
# | . | . | . | . |
# +---+---+---+---+
# | . | . | . | . |
# +---+---+---+---+

# %% [markdown]
# Q3

# %%
n = 9  
g = 2 

for row in range(n):
    for col in range(n):
        if row == 0 or row == n-1 or col == 0 or col == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print(" " * g, end="")
    for col in range(n):
        if row == 0 or row == n-1 or col == 0 or col == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()

print()

for row in range(n):
    for col in range(n):
        if row == 0 or row == n-1 or col == 0 or col == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")

    print(" " * g, end="")

    for col in range(n):
        if row == 0 or row == n-1 or col == 0 or col == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# * * * * * * * * *   * * * * * * * * *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# * * * * * * * * *   * * * * * * * * *
#
# * * * * * * * * *   * * * * * * * * *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# *               *   *               *
# * * * * * * * * *   * * * * * * * * *

# %% [markdown]
# Q4

# %%
rows = 6
cols = 6

for i in range(rows):
    for j in range(cols):
        if i == 0 or i == rows-1 or j == 0 or j == cols-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    
    print("   ", end="")  
    
   
    for j in range(cols):
        if i == 0 or i == rows-1 or j == 0 or j == cols-1:
            print("*", end=" ")
        elif i == j:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
    
    
for i in range(rows):
    
    for j in range(cols):
        if i == 0 or i == rows-1 or i == 2 or i==3 or j == 0 or j == cols-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    
    print("   ", end="")
    
    
    for j in range(cols):
        if i == 0 or i == rows-1 or j == 0 or j == cols-1 or j == i or j == cols-i-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    
    print()
# Out:
# * * * * * *    * * * * * *
# *         *    * *       *
# *         *    *   *     *
# *         *    *     *   *
# *         *    *       * *
# * * * * * *    * * * * * *
# * * * * * *    * * * * * *
# *         *    * *     * *
# * * * * * *    *   * *   *
# * * * * * *    *   * *   *
# *         *    * *     * *
# * * * * * *    * * * * * *
